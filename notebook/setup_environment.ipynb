# %% [markdown]
# # Setup All Workshop Dependencies
# ### Note: This Notebook Will Take A Few Minutes To Complete.
# ### Please Be Patient.

# %% [markdown]
# # Upgrade pip

# %%
# %pip install --upgrade pip
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pip in c:\programdata\anaconda3\lib\site-packages (24.2)
# Collecting pip
#   Using cached pip-26.0.1-py3-none-any.whl.metadata (4.7 kB)
# Using cached pip-26.0.1-py3-none-any.whl (1.8 MB)
# ERROR: To modify pip, please run the following command:
# C:\ProgramData\anaconda3\python.exe -m pip install --upgrade pip

# %% [markdown]
# # AWS

# %%
# %pip install boto3 awscli sagemaker
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting boto3
#   Downloading boto3-1.42.66-py3-none-any.whl.metadata (6.7 kB)
# Collecting awscli
#   Downloading awscli-1.44.56-py3-none-any.whl.metadata (11 kB)
# Collecting sagemaker
#   Downloading sagemaker-3.5.0-py3-none-any.whl.metadata (20 kB)
# Collecting botocore<1.43.0,>=1.42.66 (from boto3)
#   Downloading botocore-1.42.66-py3-none-any.whl.metadata (5.9 kB)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in c:\programdata\anaconda3\lib\site-packages (from boto3) (1.0.1)
# Collecting s3transfer<0.17.0,>=0.16.0 (from boto3)
#   Downloading s3transfer-0.16.0-py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: docutils<=0.19,>=0.18.1 in c:\programdata\anaconda3\lib\site-packages (from awscli) (0.18.1)
# Requirement already satisfied: PyYAML<6.1,>=3.10 in c:\programdata\anaconda3\lib\site-packages (from awscli) (6.0.1)
# Requirement already satisfied: colorama<0.4.7,>=0.2.5 in c:\programdata\anaconda3\lib\site-packages (from awscli) (0.4.6)
# Collecting rsa<4.8,>=3.1.2 (from awscli)
#   Downloading rsa-4.7.2-py3-none-any.whl.metadata (3.6 kB)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in c:\programdata\anaconda3\lib\site-packages (from botocore<1.43.0,>=1.42.66->boto3) (2.9.0.post0)
# Requirement already satisfied: urllib3!=2.2.0,<3,>=1.25.4 in c:\programdata\anaconda3\lib\site-packages (from botocore<1.43.0,>=1.42.66->boto3) (2.2.3)
# Collecting sagemaker-core<3.0.0,>=2.5.0 (from sagemaker)
#   Downloading sagemaker_core-2.5.0-py3-none-any.whl.metadata (5.5 kB)
# Collecting sagemaker-train<2.0.0,>=1.5.0 (from sagemaker)
#   Downloading sagemaker_train-1.5.0-py3-none-any.whl.metadata (7.8 kB)
# Collecting sagemaker-serve<2.0.0,>=1.5.0 (from sagemaker)
#   Downloading sagemaker_serve-1.5.0-py3-none-any.whl.metadata (14 kB)
# Collecting sagemaker-mlops<2.0.0,>=1.5.0 (from sagemaker)
#   Downloading sagemaker_mlops-1.5.0-py3-none-any.whl.metadata (18 kB)
# Requirement already satisfied: pyasn1>=0.1.3 in c:\programdata\anaconda3\lib\site-packages (from rsa<4.8,>=3.1.2->awscli) (0.4.8)
# Requirement already satisfied: pydantic<3.0.0,>=2.0.0 in c:\programdata\anaconda3\lib\site-packages (from sagemaker-core<3.0.0,>=2.5.0->sagemaker) (2.8.2)
# Requirement already satisfied: jsonschema<5.0.0 in c:\programdata\anaconda3\lib\site-packages (from sagemaker-core<3.0.0,>=2.5.0->sagemaker) (4.23.0)
# Collecting platformdirs<5.0.0,>=4.0.0 (from sagemaker-core<3.0.0,>=2.5.0->sagemaker)
#   Downloading platformdirs-4.9.4-py3-none-any.whl.metadata (4.7 kB)
# Requirement already satisfied: rich<14.0.0,>=13.0.0 in c:\programdata\anaconda3\lib\site-packages (from sagemaker-core<3.0.0,>=2.5.0->sagemaker) (13.7.1)
# Collecting mock<5.0,>4.0 (from sagemaker-core<3.0.0,>=2.5.0->sagemaker)
#   Downloading mock-4.0.3-py3-none-any.whl.metadata (2.8 kB)
# Collecting importlib-metadata<7.0,>=1.4.0 (from sagemaker-core<3.0.0,>=2.5.0->sagemaker)
#   Downloading importlib_metadata-6.11.0-py3-none-any.whl.metadata (4.9 kB)
# Requirement already satisfied: typing_extensions>=4.9.0 in c:\programdata\anaconda3\lib\site-packages (from sagemaker-core<3.0.0,>=2.5.0->sagemaker) (4.11.0)
# Requirement already satisfied: pytz>=2021.1 in c:\programdata\anaconda3\lib\site-packages (from sagemaker-core<3.0.0,>=2.5.0->sagemaker) (2024.1)
# Requirement already satisfied: requests<3.0.0,>=2.20.0 in c:\programdata\anaconda3\lib\site-packages (from sagemaker-core<3.0.0,>=2.5.0->sagemaker) (2.32.3)
# Requirement already satisfied: attrs>=20.3.0 in c:\programdata\anaconda3\lib\site-packages (from sagemaker-core<3.0.0,>=2.5.0->sagemaker) (23.1.0)
# Requirement already satisfied: packaging>=20.0 in c:\programdata\anaconda3\lib\site-packages (from sagemaker-core<3.0.0,>=2.5.0->sagemaker) (24.1)
# Requirement already satisfied: protobuf<7.0.0,>=3.12 in c:\programdata\anaconda3\lib\site-packages (from sagemaker-core<3.0.0,>=2.5.0->sagemaker) (4.25.3)
# Requirement already satisfied: pandas>=1.0.0 in c:\programdata\anaconda3\lib\site-packages (from sagemaker-core<3.0.0,>=2.5.0->sagemaker) (2.2.2)
# Requirement already satisfied: numpy>=1.9.0 in c:\programdata\anaconda3\lib\site-packages (from sagemaker-core<3.0.0,>=2.5.0->sagemaker) (1.26.4)
# Collecting smdebug_rulesconfig>=1.0.1 (from sagemaker-core<3.0.0,>=2.5.0->sagemaker)
#   Downloading smdebug_rulesconfig-1.0.1-py2.py3-none-any.whl.metadata (943 bytes)
# Collecting schema>=0.7.5 (from sagemaker-core<3.0.0,>=2.5.0->sagemaker)
#   Downloading schema-0.7.8-py2.py3-none-any.whl.metadata (34 kB)
# Collecting omegaconf>=2.1.0 (from sagemaker-core<3.0.0,>=2.5.0->sagemaker)
#   Downloading omegaconf-2.3.0-py3-none-any.whl.metadata (3.9 kB)
# Collecting torch>=1.9.0 (from sagemaker-core<3.0.0,>=2.5.0->sagemaker)
#   Downloading torch-2.10.0-cp312-cp312-win_amd64.whl.metadata (31 kB)
# Requirement already satisfied: scipy>=1.5.0 in c:\programdata\anaconda3\lib\site-packages (from sagemaker-core<3.0.0,>=2.5.0->sagemaker) (1.13.1)
# Requirement already satisfied: cloudpickle>=2.0.0 in c:\programdata\anaconda3\lib\site-packages (from sagemaker-core<3.0.0,>=2.5.0->sagemaker) (3.0.0)
# Collecting paramiko>=2.11.0 (from sagemaker-core<3.0.0,>=2.5.0->sagemaker)
#   Downloading paramiko-4.0.0-py3-none-any.whl.metadata (3.9 kB)
# Requirement already satisfied: tblib>=1.7.0 in c:\programdata\anaconda3\lib\site-packages (from sagemaker-core<3.0.0,>=2.5.0->sagemaker) (1.7.0)
# Collecting deepdiff (from sagemaker-serve<2.0.0,>=1.5.0->sagemaker)
#   Downloading deepdiff-8.6.1-py3-none-any.whl.metadata (8.6 kB)
# Collecting mlflow (from sagemaker-serve<2.0.0,>=1.5.0->sagemaker)
#   Downloading mlflow-3.10.1-py3-none-any.whl.metadata (31 kB)
# Collecting sagemaker_schema_inference_artifacts (from sagemaker-serve<2.0.0,>=1.5.0->sagemaker)
#   Downloading sagemaker_schema_inference_artifacts-0.0.5-py3-none-any.whl.metadata (2.3 kB)
# Requirement already satisfied: pytest in c:\programdata\anaconda3\lib\site-packages (from sagemaker-serve<2.0.0,>=1.5.0->sagemaker) (7.4.4)
# Requirement already satisfied: tqdm in c:\programdata\anaconda3\lib\site-packages (from sagemaker-serve<2.0.0,>=1.5.0->sagemaker) (4.66.5)
# Requirement already satisfied: psutil in c:\programdata\anaconda3\lib\site-packages (from sagemaker-serve<2.0.0,>=1.5.0->sagemaker) (5.9.0)
# Collecting tritonclient[http] (from sagemaker-serve<2.0.0,>=1.5.0->sagemaker)
#   Downloading tritonclient-2.66.0-py3-none-any.whl.metadata (3.0 kB)
# Collecting onnx (from sagemaker-serve<2.0.0,>=1.5.0->sagemaker)
#   Downloading onnx-1.20.1-cp312-abi3-win_amd64.whl.metadata (8.6 kB)
# Collecting onnxruntime (from sagemaker-serve<2.0.0,>=1.5.0->sagemaker)
#   Downloading onnxruntime-1.24.3-cp312-cp312-win_amd64.whl.metadata (5.3 kB)
# Collecting graphene<4,>=3 (from sagemaker-train<2.0.0,>=1.5.0->sagemaker)
#   Downloading graphene-3.4.3-py2.py3-none-any.whl.metadata (6.9 kB)
# Requirement already satisfied: jinja2<4.0,>=3.0 in c:\programdata\anaconda3\lib\site-packages (from sagemaker-train<2.0.0,>=1.5.0->sagemaker) (3.1.4)
# Collecting sagemaker-mlflow<1.0.0,>=0.0.1 (from sagemaker-train<2.0.0,>=1.5.0->sagemaker)
#   Downloading sagemaker_mlflow-0.2.0-py3-none-any.whl.metadata (3.9 kB)
# Requirement already satisfied: nest_asyncio>=1.5.0 in c:\programdata\anaconda3\lib\site-packages (from sagemaker-train<2.0.0,>=1.5.0->sagemaker) (1.6.0)
# Collecting graphql-core<3.3,>=3.1 (from graphene<4,>=3->sagemaker-train<2.0.0,>=1.5.0->sagemaker)
#   Downloading graphql_core-3.2.8-py3-none-any.whl.metadata (11 kB)
# Collecting graphql-relay<3.3,>=3.1 (from graphene<4,>=3->sagemaker-train<2.0.0,>=1.5.0->sagemaker)
#   Downloading graphql_relay-3.2.0-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: zipp>=0.5 in c:\programdata\anaconda3\lib\site-packages (from importlib-metadata<7.0,>=1.4.0->sagemaker-core<3.0.0,>=2.5.0->sagemaker) (3.17.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\programdata\anaconda3\lib\site-packages (from jinja2<4.0,>=3.0->sagemaker-train<2.0.0,>=1.5.0->sagemaker) (2.1.3)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\programdata\anaconda3\lib\site-packages (from jsonschema<5.0.0->sagemaker-core<3.0.0,>=2.5.0->sagemaker) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\programdata\anaconda3\lib\site-packages (from jsonschema<5.0.0->sagemaker-core<3.0.0,>=2.5.0->sagemaker) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\programdata\anaconda3\lib\site-packages (from jsonschema<5.0.0->sagemaker-core<3.0.0,>=2.5.0->sagemaker) (0.10.6)
# Collecting mlflow-skinny==3.10.1 (from mlflow->sagemaker-serve<2.0.0,>=1.5.0->sagemaker)
#   Downloading mlflow_skinny-3.10.1-py3-none-any.whl.metadata (32 kB)
# Collecting mlflow-tracing==3.10.1 (from mlflow->sagemaker-serve<2.0.0,>=1.5.0->sagemaker)
#   Downloading mlflow_tracing-3.10.1-py3-none-any.whl.metadata (19 kB)
# Collecting Flask-CORS<7 (from mlflow->sagemaker-serve<2.0.0,>=1.5.0->sagemaker)
#   Downloading flask_cors-6.0.2-py3-none-any.whl.metadata (5.3 kB)
# Requirement already satisfied: Flask<4 in c:\programdata\anaconda3\lib\site-packages (from mlflow->sagemaker-serve<2.0.0,>=1.5.0->sagemaker) (3.0.3)
# Requirement already satisfied: alembic!=1.10.0,<2 in c:\programdata\anaconda3\lib\site-packages (from mlflow->sagemaker-serve<2.0.0,>=1.5.0->sagemaker) (1.13.3)
# Requirement already satisfied: cryptography<47,>=43.0.0 in c:\programdata\anaconda3\lib\site-packages (from mlflow->sagemaker-serve<2.0.0,>=1.5.0->sagemaker) (43.0.0)
# Collecting docker<8,>=4.0.0 (from mlflow->sagemaker-serve<2.0.0,>=1.5.0->sagemaker)
#   Downloading docker-7.1.0-py3-none-any.whl.metadata (3.8 kB)
# Collecting huey<3,>=2.5.4 (from mlflow->sagemaker-serve<2.0.0,>=1.5.0->sagemaker)
#   Downloading huey-2.6.0-py3-none-any.whl.metadata (4.3 kB)
# Requirement already satisfied: matplotlib<4 in c:\programdata\anaconda3\lib\site-packages (from mlflow->sagemaker-serve<2.0.0,>=1.5.0->sagemaker) (3.9.2)
# Requirement already satisfied: pyarrow<24,>=4.0.0 in c:\programdata\anaconda3\lib\site-packages (from mlflow->sagemaker-serve<2.0.0,>=1.5.0->sagemaker) (16.1.0)
# Requirement already satisfied: scikit-learn<2 in c:\programdata\anaconda3\lib\site-packages (from mlflow->sagemaker-serve<2.0.0,>=1.5.0->sagemaker) (1.5.1)
# Collecting skops<1 (from mlflow->sagemaker-serve<2.0.0,>=1.5.0->sagemaker)
#   Downloading skops-0.13.0-py3-none-any.whl.metadata (5.6 kB)
# Requirement already satisfied: sqlalchemy<3,>=1.4.0 in c:\programdata\anaconda3\lib\site-packages (from mlflow->sagemaker-serve<2.0.0,>=1.5.0->sagemaker) (2.0.34)
# Collecting waitress<4 (from mlflow->sagemaker-serve<2.0.0,>=1.5.0->sagemaker)
#   Downloading waitress-3.0.2-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: cachetools<8,>=5.0.0 in c:\programdata\anaconda3\lib\site-packages (from mlflow-skinny==3.10.1->mlflow->sagemaker-serve<2.0.0,>=1.5.0->sagemaker) (5.3.3)
# Requirement already satisfied: click<9,>=7.0 in c:\programdata\anaconda3\lib\site-packages (from mlflow-skinny==3.10.1->mlflow->sagemaker-serve<2.0.0,>=1.5.0->sagemaker) (8.1.7)
# Collecting databricks-sdk<1,>=0.20.0 (from mlflow-skinny==3.10.1->mlflow->sagemaker-serve<2.0.0,>=1.5.0->sagemaker)
#   Downloading databricks_sdk-0.98.0-py3-none-any.whl.metadata (40 kB)
# Collecting fastapi<1 (from mlflow-skinny==3.10.1->mlflow->sagemaker-serve<2.0.0,>=1.5.0->sagemaker)
#   Downloading fastapi-0.135.1-py3-none-any.whl.metadata (30 kB)
# Requirement already satisfied: gitpython<4,>=3.1.9 in c:\programdata\anaconda3\lib\site-packages (from mlflow-skinny==3.10.1->mlflow->sagemaker-serve<2.0.0,>=1.5.0->sagemaker) (3.1.43)
# Collecting opentelemetry-api<3,>=1.9.0 (from mlflow-skinny==3.10.1->mlflow->sagemaker-serve<2.0.0,>=1.5.0->sagemaker)
#   Downloading opentelemetry_api-1.40.0-py3-none-any.whl.metadata (1.5 kB)
# Collecting opentelemetry-proto<3,>=1.9.0 (from mlflow-skinny==3.10.1->mlflow->sagemaker-serve<2.0.0,>=1.5.0->sagemaker)
#   Downloading opentelemetry_proto-1.40.0-py3-none-any.whl.metadata (2.4 kB)
# Collecting opentelemetry-sdk<3,>=1.9.0 (from mlflow-skinny==3.10.1->mlflow->sagemaker-serve<2.0.0,>=1.5.0->sagemaker)
#   Downloading opentelemetry_sdk-1.40.0-py3-none-any.whl.metadata (1.6 kB)
# Requirement already satisfied: python-dotenv<2,>=0.19.0 in c:\programdata\anaconda3\lib\site-packages (from mlflow-skinny==3.10.1->mlflow->sagemaker-serve<2.0.0,>=1.5.0->sagemaker) (0.21.0)
# Collecting sqlparse<1,>=0.4.0 (from mlflow-skinny==3.10.1->mlflow->sagemaker-serve<2.0.0,>=1.5.0->sagemaker)
#   Downloading sqlparse-0.5.5-py3-none-any.whl.metadata (4.7 kB)
# Collecting uvicorn<1 (from mlflow-skinny==3.10.1->mlflow->sagemaker-serve<2.0.0,>=1.5.0->sagemaker)
#   Downloading uvicorn-0.41.0-py3-none-any.whl.metadata (6.7 kB)
# Collecting antlr4-python3-runtime==4.9.* (from omegaconf>=2.1.0->sagemaker-core<3.0.0,>=2.5.0->sagemaker)
#   Downloading antlr4-python3-runtime-4.9.3.tar.gz (117 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: tzdata>=2022.7 in c:\programdata\anaconda3\lib\site-packages (from pandas>=1.0.0->sagemaker-core<3.0.0,>=2.5.0->sagemaker) (2023.3)
# Requirement already satisfied: bcrypt>=3.2 in c:\programdata\anaconda3\lib\site-packages (from paramiko>=2.11.0->sagemaker-core<3.0.0,>=2.5.0->sagemaker) (3.2.0)
# Collecting invoke>=2.0 (from paramiko>=2.11.0->sagemaker-core<3.0.0,>=2.5.0->sagemaker)
#   Downloading invoke-2.2.1-py3-none-any.whl.metadata (3.3 kB)
# Requirement already satisfied: pynacl>=1.5 in c:\programdata\anaconda3\lib\site-packages (from paramiko>=2.11.0->sagemaker-core<3.0.0,>=2.5.0->sagemaker) (1.5.0)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\programdata\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.0.0->sagemaker-core<3.0.0,>=2.5.0->sagemaker) (0.6.0)
# Requirement already satisfied: pydantic-core==2.20.1 in c:\programdata\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.0.0->sagemaker-core<3.0.0,>=2.5.0->sagemaker) (2.20.1)
# Requirement already satisfied: six>=1.5 in c:\programdata\anaconda3\lib\site-packages (from python-dateutil<3.0.0,>=2.1->botocore<1.43.0,>=1.42.66->boto3) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\programdata\anaconda3\lib\site-packages (from requests<3.0.0,>=2.20.0->sagemaker-core<3.0.0,>=2.5.0->sagemaker) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\programdata\anaconda3\lib\site-packages (from requests<3.0.0,>=2.20.0->sagemaker-core<3.0.0,>=2.5.0->sagemaker) (3.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\programdata\anaconda3\lib\site-packages (from requests<3.0.0,>=2.20.0->sagemaker-core<3.0.0,>=2.5.0->sagemaker) (2025.8.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\programdata\anaconda3\lib\site-packages (from rich<14.0.0,>=13.0.0->sagemaker-core<3.0.0,>=2.5.0->sagemaker) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\programdata\anaconda3\lib\site-packages (from rich<14.0.0,>=13.0.0->sagemaker-core<3.0.0,>=2.5.0->sagemaker) (2.15.1)
# Requirement already satisfied: filelock in c:\programdata\anaconda3\lib\site-packages (from torch>=1.9.0->sagemaker-core<3.0.0,>=2.5.0->sagemaker) (3.13.1)
# Collecting sympy>=1.13.3 (from torch>=1.9.0->sagemaker-core<3.0.0,>=2.5.0->sagemaker)
#   Downloading sympy-1.14.0-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: networkx>=2.5.1 in c:\programdata\anaconda3\lib\site-packages (from torch>=1.9.0->sagemaker-core<3.0.0,>=2.5.0->sagemaker) (3.3)
# Requirement already satisfied: fsspec>=0.8.5 in c:\programdata\anaconda3\lib\site-packages (from torch>=1.9.0->sagemaker-core<3.0.0,>=2.5.0->sagemaker) (2024.6.1)
# Requirement already satisfied: setuptools in c:\programdata\anaconda3\lib\site-packages (from torch>=1.9.0->sagemaker-core<3.0.0,>=2.5.0->sagemaker) (75.1.0)
# Collecting orderly-set<6,>=5.4.1 (from deepdiff->sagemaker-serve<2.0.0,>=1.5.0->sagemaker)
#   Downloading orderly_set-5.5.0-py3-none-any.whl.metadata (6.6 kB)
# Collecting ml_dtypes>=0.5.0 (from onnx->sagemaker-serve<2.0.0,>=1.5.0->sagemaker)
#   Downloading ml_dtypes-0.5.4-cp312-cp312-win_amd64.whl.metadata (9.2 kB)
# Collecting flatbuffers (from onnxruntime->sagemaker-serve<2.0.0,>=1.5.0->sagemaker)
#   Downloading flatbuffers-25.12.19-py2.py3-none-any.whl.metadata (1.0 kB)
# Requirement already satisfied: iniconfig in c:\programdata\anaconda3\lib\site-packages (from pytest->sagemaker-serve<2.0.0,>=1.5.0->sagemaker) (1.1.1)
# Requirement already satisfied: pluggy<2.0,>=0.12 in c:\programdata\anaconda3\lib\site-packages (from pytest->sagemaker-serve<2.0.0,>=1.5.0->sagemaker) (1.0.0)
# Collecting json5>=0.9.22 (from sagemaker_schema_inference_artifacts->sagemaker-serve<2.0.0,>=1.5.0->sagemaker)
#   Downloading json5-0.13.0-py3-none-any.whl.metadata (36 kB)
# Collecting python-rapidjson>=0.9.1 (from tritonclient[http]->sagemaker-serve<2.0.0,>=1.5.0->sagemaker)
#   Downloading python_rapidjson-1.23-cp312-cp312-win_amd64.whl.metadata (25 kB)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.1 in c:\programdata\anaconda3\lib\site-packages (from tritonclient[http]->sagemaker-serve<2.0.0,>=1.5.0->sagemaker) (3.10.5)
# Collecting geventhttpclient>=2.3.3 (from tritonclient[http]->sagemaker-serve<2.0.0,>=1.5.0->sagemaker)
#   Downloading geventhttpclient-2.3.9-cp312-cp312-win_amd64.whl.metadata (8.7 kB)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in c:\programdata\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.1->tritonclient[http]->sagemaker-serve<2.0.0,>=1.5.0->sagemaker) (2.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\programdata\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.1->tritonclient[http]->sagemaker-serve<2.0.0,>=1.5.0->sagemaker) (1.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\programdata\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.1->tritonclient[http]->sagemaker-serve<2.0.0,>=1.5.0->sagemaker) (1.4.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\programdata\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.1->tritonclient[http]->sagemaker-serve<2.0.0,>=1.5.0->sagemaker) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\programdata\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.1->tritonclient[http]->sagemaker-serve<2.0.0,>=1.5.0->sagemaker) (1.11.0)
# Requirement already satisfied: Mako in c:\programdata\anaconda3\lib\site-packages (from alembic!=1.10.0,<2->mlflow->sagemaker-serve<2.0.0,>=1.5.0->sagemaker) (1.2.3)
# Requirement already satisfied: cffi>=1.1 in c:\programdata\anaconda3\lib\site-packages (from bcrypt>=3.2->paramiko>=2.11.0->sagemaker-core<3.0.0,>=2.5.0->sagemaker) (1.17.1)
# Requirement already satisfied: pywin32>=304 in c:\programdata\anaconda3\lib\site-packages (from docker<8,>=4.0.0->mlflow->sagemaker-serve<2.0.0,>=1.5.0->sagemaker) (305.1)
# Requirement already satisfied: Werkzeug>=3.0.0 in c:\programdata\anaconda3\lib\site-packages (from Flask<4->mlflow->sagemaker-serve<2.0.0,>=1.5.0->sagemaker) (3.0.3)
# Requirement already satisfied: itsdangerous>=2.1.2 in c:\programdata\anaconda3\lib\site-packages (from Flask<4->mlflow->sagemaker-serve<2.0.0,>=1.5.0->sagemaker) (2.2.0)
# Requirement already satisfied: blinker>=1.6.2 in c:\programdata\anaconda3\lib\site-packages (from Flask<4->mlflow->sagemaker-serve<2.0.0,>=1.5.0->sagemaker) (1.6.2)
# Collecting gevent (from geventhttpclient>=2.3.3->tritonclient[http]->sagemaker-serve<2.0.0,>=1.5.0->sagemaker)
#   Downloading gevent-25.9.1-cp312-cp312-win_amd64.whl.metadata (14 kB)
# Requirement already satisfied: brotli in c:\programdata\anaconda3\lib\site-packages (from geventhttpclient>=2.3.3->tritonclient[http]->sagemaker-serve<2.0.0,>=1.5.0->sagemaker) (1.0.9)
# Requirement already satisfied: mdurl~=0.1 in c:\programdata\anaconda3\lib\site-packages (from markdown-it-py>=2.2.0->rich<14.0.0,>=13.0.0->sagemaker-core<3.0.0,>=2.5.0->sagemaker) (0.1.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\programdata\anaconda3\lib\site-packages (from matplotlib<4->mlflow->sagemaker-serve<2.0.0,>=1.5.0->sagemaker) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\programdata\anaconda3\lib\site-packages (from matplotlib<4->mlflow->sagemaker-serve<2.0.0,>=1.5.0->sagemaker) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\programdata\anaconda3\lib\site-packages (from matplotlib<4->mlflow->sagemaker-serve<2.0.0,>=1.5.0->sagemaker) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\programdata\anaconda3\lib\site-packages (from matplotlib<4->mlflow->sagemaker-serve<2.0.0,>=1.5.0->sagemaker) (1.4.4)
# Requirement already satisfied: pillow>=8 in c:\programdata\anaconda3\lib\site-packages (from matplotlib<4->mlflow->sagemaker-serve<2.0.0,>=1.5.0->sagemaker) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\programdata\anaconda3\lib\site-packages (from matplotlib<4->mlflow->sagemaker-serve<2.0.0,>=1.5.0->sagemaker) (3.1.2)
# Requirement already satisfied: joblib>=1.2.0 in c:\programdata\anaconda3\lib\site-packages (from scikit-learn<2->mlflow->sagemaker-serve<2.0.0,>=1.5.0->sagemaker) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\programdata\anaconda3\lib\site-packages (from scikit-learn<2->mlflow->sagemaker-serve<2.0.0,>=1.5.0->sagemaker) (3.5.0)
# Collecting prettytable>=3.9 (from skops<1->mlflow->sagemaker-serve<2.0.0,>=1.5.0->sagemaker)
#   Downloading prettytable-3.17.0-py3-none-any.whl.metadata (34 kB)
# Requirement already satisfied: greenlet!=0.4.17 in c:\programdata\anaconda3\lib\site-packages (from sqlalchemy<3,>=1.4.0->mlflow->sagemaker-serve<2.0.0,>=1.5.0->sagemaker) (3.0.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\programdata\anaconda3\lib\site-packages (from sympy>=1.13.3->torch>=1.9.0->sagemaker-core<3.0.0,>=2.5.0->sagemaker) (1.3.0)
# Requirement already satisfied: pycparser in c:\programdata\anaconda3\lib\site-packages (from cffi>=1.1->bcrypt>=3.2->paramiko>=2.11.0->sagemaker-core<3.0.0,>=2.5.0->sagemaker) (2.21)
# Collecting google-auth~=2.0 (from databricks-sdk<1,>=0.20.0->mlflow-skinny==3.10.1->mlflow->sagemaker-serve<2.0.0,>=1.5.0->sagemaker)
#   Downloading google_auth-2.49.0-py3-none-any.whl.metadata (6.2 kB)
# Collecting protobuf<7.0.0,>=3.12 (from sagemaker-core<3.0.0,>=2.5.0->sagemaker)
#   Using cached protobuf-6.33.5-cp310-abi3-win_amd64.whl.metadata (593 bytes)
# Collecting starlette>=0.46.0 (from fastapi<1->mlflow-skinny==3.10.1->mlflow->sagemaker-serve<2.0.0,>=1.5.0->sagemaker)
#   Downloading starlette-0.52.1-py3-none-any.whl.metadata (6.3 kB)
# Collecting typing-inspection>=0.4.2 (from fastapi<1->mlflow-skinny==3.10.1->mlflow->sagemaker-serve<2.0.0,>=1.5.0->sagemaker)
#   Downloading typing_inspection-0.4.2-py3-none-any.whl.metadata (2.6 kB)
# Collecting annotated-doc>=0.0.2 (from fastapi<1->mlflow-skinny==3.10.1->mlflow->sagemaker-serve<2.0.0,>=1.5.0->sagemaker)
#   Downloading annotated_doc-0.0.4-py3-none-any.whl.metadata (6.6 kB)
# Requirement already satisfied: gitdb<5,>=4.0.1 in c:\programdata\anaconda3\lib\site-packages (from gitpython<4,>=3.1.9->mlflow-skinny==3.10.1->mlflow->sagemaker-serve<2.0.0,>=1.5.0->sagemaker) (4.0.7)
# Collecting opentelemetry-semantic-conventions==0.61b0 (from opentelemetry-sdk<3,>=1.9.0->mlflow-skinny==3.10.1->mlflow->sagemaker-serve<2.0.0,>=1.5.0->sagemaker)
#   Downloading opentelemetry_semantic_conventions-0.61b0-py3-none-any.whl.metadata (2.5 kB)
# Requirement already satisfied: wcwidth in c:\programdata\anaconda3\lib\site-packages (from prettytable>=3.9->skops<1->mlflow->sagemaker-serve<2.0.0,>=1.5.0->sagemaker) (0.2.5)
# Requirement already satisfied: h11>=0.8 in c:\programdata\anaconda3\lib\site-packages (from uvicorn<1->mlflow-skinny==3.10.1->mlflow->sagemaker-serve<2.0.0,>=1.5.0->sagemaker) (0.14.0)
# Collecting greenlet!=0.4.17 (from sqlalchemy<3,>=1.4.0->mlflow->sagemaker-serve<2.0.0,>=1.5.0->sagemaker)
#   Downloading greenlet-3.3.2-cp312-cp312-win_amd64.whl.metadata (3.8 kB)
# Collecting zope.event (from gevent->geventhttpclient>=2.3.3->tritonclient[http]->sagemaker-serve<2.0.0,>=1.5.0->sagemaker)
#   Downloading zope_event-6.1-py3-none-any.whl.metadata (5.1 kB)
# Requirement already satisfied: zope.interface in c:\programdata\anaconda3\lib\site-packages (from gevent->geventhttpclient>=2.3.3->tritonclient[http]->sagemaker-serve<2.0.0,>=1.5.0->sagemaker) (5.4.0)
# Requirement already satisfied: smmap<5,>=3.0.1 in c:\programdata\anaconda3\lib\site-packages (from gitdb<5,>=4.0.1->gitpython<4,>=3.1.9->mlflow-skinny==3.10.1->mlflow->sagemaker-serve<2.0.0,>=1.5.0->sagemaker) (4.0.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\programdata\anaconda3\lib\site-packages (from google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==3.10.1->mlflow->sagemaker-serve<2.0.0,>=1.5.0->sagemaker) (0.2.8)
# Requirement already satisfied: anyio<5,>=3.6.2 in c:\programdata\anaconda3\lib\site-packages (from starlette>=0.46.0->fastapi<1->mlflow-skinny==3.10.1->mlflow->sagemaker-serve<2.0.0,>=1.5.0->sagemaker) (4.2.0)
# Collecting typing_extensions>=4.9.0 (from sagemaker-core<3.0.0,>=2.5.0->sagemaker)
#   Using cached typing_extensions-4.15.0-py3-none-any.whl.metadata (3.3 kB)
# Requirement already satisfied: sniffio>=1.1 in c:\programdata\anaconda3\lib\site-packages (from anyio<5,>=3.6.2->starlette>=0.46.0->fastapi<1->mlflow-skinny==3.10.1->mlflow->sagemaker-serve<2.0.0,>=1.5.0->sagemaker) (1.3.0)
# Downloading boto3-1.42.66-py3-none-any.whl (140 kB)
# Downloading awscli-1.44.56-py3-none-any.whl (4.6 MB)
#    ---------------------------------------- 0.0/4.6 MB ? eta -:--:--
#    ----------------------------- ---------- 3.4/4.6 MB 25.2 MB/s eta 0:00:01
#    ---------------------------------------- 4.6/4.6 MB 17.4 MB/s eta 0:00:00
# Downloading botocore-1.42.66-py3-none-any.whl (14.7 MB)
#    ---------------------------------------- 0.0/14.7 MB ? eta -:--:--
#    -------------------- ------------------- 7.6/14.7 MB 36.2 MB/s eta 0:00:01
#    -------------------------------------- - 14.2/14.7 MB 32.9 MB/s eta 0:00:01
#    ---------------------------------------- 14.7/14.7 MB 31.8 MB/s eta 0:00:00
# Downloading sagemaker-3.5.0-py3-none-any.whl (11 kB)
# Downloading rsa-4.7.2-py3-none-any.whl (34 kB)
# Downloading s3transfer-0.16.0-py3-none-any.whl (86 kB)
# Downloading sagemaker_core-2.5.0-py3-none-any.whl (1.3 MB)
#    ---------------------------------------- 0.0/1.3 MB ? eta -:--:--
#    ---------------------------------------- 1.3/1.3 MB 6.8 MB/s eta 0:00:00
# Downloading sagemaker_mlops-1.5.0-py3-none-any.whl (137 kB)
# Downloading sagemaker_serve-1.5.0-py3-none-any.whl (216 kB)
# Downloading sagemaker_train-1.5.0-py3-none-any.whl (251 kB)
# Downloading graphene-3.4.3-py2.py3-none-any.whl (114 kB)
# Downloading importlib_metadata-6.11.0-py3-none-any.whl (23 kB)
# Downloading mlflow-3.10.1-py3-none-any.whl (10.2 MB)
#    ---------------------------------------- 0.0/10.2 MB ? eta -:--:--
#    ----------------------- ---------------- 6.0/10.2 MB 30.8 MB/s eta 0:00:01
#    ---------------------------------------- 10.2/10.2 MB 33.3 MB/s eta 0:00:00
# Downloading mlflow_skinny-3.10.1-py3-none-any.whl (3.0 MB)
#    ---------------------------------------- 0.0/3.0 MB ? eta -:--:--
#    ---------------------------------------- 3.0/3.0 MB 43.3 MB/s eta 0:00:00
# Downloading mlflow_tracing-3.10.1-py3-none-any.whl (1.5 MB)
#    ---------------------------------------- 0.0/1.5 MB ? eta -:--:--
#    ---------------------------------------- 1.5/1.5 MB 39.8 MB/s eta 0:00:00
# Downloading mock-4.0.3-py3-none-any.whl (28 kB)
# Downloading omegaconf-2.3.0-py3-none-any.whl (79 kB)
# Downloading paramiko-4.0.0-py3-none-any.whl (223 kB)
# Downloading platformdirs-4.9.4-py3-none-any.whl (21 kB)
# Downloading sagemaker_mlflow-0.2.0-py3-none-any.whl (19 kB)
# Downloading schema-0.7.8-py2.py3-none-any.whl (19 kB)
# Downloading smdebug_rulesconfig-1.0.1-py2.py3-none-any.whl (20 kB)
# Downloading torch-2.10.0-cp312-cp312-win_amd64.whl (113.8 MB)
#    ---------------------------------------- 0.0/113.8 MB ? eta -:--:--
#    - -------------------------------------- 3.7/113.8 MB 36.3 MB/s eta 0:00:04
#    ---- ----------------------------------- 13.6/113.8 MB 31.7 MB/s eta 0:00:04
#    ------ --------------------------------- 18.4/113.8 MB 27.6 MB/s eta 0:00:04
#    -------- ------------------------------- 24.9/113.8 MB 28.7 MB/s eta 0:00:04
#    ----------- ---------------------------- 31.5/113.8 MB 28.9 MB/s eta 0:00:03
#    -------------- ------------------------- 39.8/113.8 MB 30.5 MB/s eta 0:00:03
#    ---------------- ----------------------- 46.9/113.8 MB 30.8 MB/s eta 0:00:03
#    ------------------- -------------------- 54.3/113.8 MB 31.4 MB/s eta 0:00:02
#    ---------------------- ----------------- 62.7/113.8 MB 32.5 MB/s eta 0:00:02
#    ------------------------ --------------- 70.5/113.8 MB 32.8 MB/s eta 0:00:02
#    --------------------------- ------------ 77.9/113.8 MB 33.1 MB/s eta 0:00:02
#    ---------------------------- ----------- 82.1/113.8 MB 31.9 MB/s eta 0:00:01
#    ------------------------------- -------- 88.6/113.8 MB 31.8 MB/s eta 0:00:01
#    --------------------------------- ------ 96.5/113.8 MB 32.2 MB/s eta 0:00:01
#    ----------------------------------- --- 103.5/113.8 MB 32.2 MB/s eta 0:00:01
#    --------------------------------------  110.9/113.8 MB 32.5 MB/s eta 0:00:01
#    --------------------------------------  113.5/113.8 MB 32.5 MB/s eta 0:00:01
#    --------------------------------------- 113.8/113.8 MB 31.0 MB/s eta 0:00:00
# Downloading deepdiff-8.6.1-py3-none-any.whl (91 kB)
# Downloading onnx-1.20.1-cp312-abi3-win_amd64.whl (16.4 MB)
#    ---------------------------------------- 0.0/16.4 MB ? eta -:--:--
#    ------------------ --------------------- 7.6/16.4 MB 36.2 MB/s eta 0:00:01
#    ----------------------------------- ---- 14.7/16.4 MB 35.5 MB/s eta 0:00:01
#    ---------------------------------------- 16.4/16.4 MB 32.3 MB/s eta 0:00:00
# Downloading onnxruntime-1.24.3-cp312-cp312-win_amd64.whl (12.6 MB)
#    ---------------------------------------- 0.0/12.6 MB ? eta -:--:--
#    ---------------- ----------------------- 5.2/12.6 MB 26.6 MB/s eta 0:00:01
#    ----------------------------------- ---- 11.3/12.6 MB 28.2 MB/s eta 0:00:01
#    ---------------------------------------- 12.6/12.6 MB 26.3 MB/s eta 0:00:00
# Downloading sagemaker_schema_inference_artifacts-0.0.5-py3-none-any.whl (621 kB)
#    ---------------------------------------- 0.0/621.9 kB ? eta -:--:--
#    --------------------------------------- 621.9/621.9 kB 22.5 MB/s eta 0:00:00
# Downloading docker-7.1.0-py3-none-any.whl (147 kB)
# Downloading flask_cors-6.0.2-py3-none-any.whl (13 kB)
# Downloading geventhttpclient-2.3.9-cp312-cp312-win_amd64.whl (49 kB)
# Downloading graphql_core-3.2.8-py3-none-any.whl (207 kB)
# Downloading graphql_relay-3.2.0-py3-none-any.whl (16 kB)
# Downloading huey-2.6.0-py3-none-any.whl (76 kB)
# Downloading invoke-2.2.1-py3-none-any.whl (160 kB)
# Downloading json5-0.13.0-py3-none-any.whl (36 kB)
# Downloading ml_dtypes-0.5.4-cp312-cp312-win_amd64.whl (212 kB)
# Downloading orderly_set-5.5.0-py3-none-any.whl (13 kB)
# Downloading python_rapidjson-1.23-cp312-cp312-win_amd64.whl (151 kB)
# Downloading skops-0.13.0-py3-none-any.whl (131 kB)
# Downloading sympy-1.14.0-py3-none-any.whl (6.3 MB)
#    ---------------------------------------- 0.0/6.3 MB ? eta -:--:--
#    ---------------------------------------- 6.3/6.3 MB 29.7 MB/s eta 0:00:00
# Downloading waitress-3.0.2-py3-none-any.whl (56 kB)
# Downloading flatbuffers-25.12.19-py2.py3-none-any.whl (26 kB)
# Downloading tritonclient-2.66.0-py3-none-any.whl (98 kB)
# Downloading databricks_sdk-0.98.0-py3-none-any.whl (828 kB)
#    ---------------------------------------- 0.0/828.0 kB ? eta -:--:--
#    --------------------------------------- 828.0/828.0 kB 37.7 MB/s eta 0:00:00
# Using cached protobuf-6.33.5-cp310-abi3-win_amd64.whl (437 kB)
# Downloading fastapi-0.135.1-py3-none-any.whl (116 kB)
# Downloading opentelemetry_api-1.40.0-py3-none-any.whl (68 kB)
# Downloading opentelemetry_proto-1.40.0-py3-none-any.whl (72 kB)
# Downloading opentelemetry_sdk-1.40.0-py3-none-any.whl (141 kB)
# Downloading opentelemetry_semantic_conventions-0.61b0-py3-none-any.whl (231 kB)
# Downloading prettytable-3.17.0-py3-none-any.whl (34 kB)
# Downloading sqlparse-0.5.5-py3-none-any.whl (46 kB)
# Downloading uvicorn-0.41.0-py3-none-any.whl (68 kB)
# Downloading gevent-25.9.1-cp312-cp312-win_amd64.whl (1.7 MB)
#    ---------------------------------------- 0.0/1.7 MB ? eta -:--:--
#    ---------------------------------------- 1.7/1.7 MB 30.2 MB/s eta 0:00:00
# Downloading greenlet-3.3.2-cp312-cp312-win_amd64.whl (231 kB)
# Downloading annotated_doc-0.0.4-py3-none-any.whl (5.3 kB)
# Downloading google_auth-2.49.0-py3-none-any.whl (240 kB)
# Downloading starlette-0.52.1-py3-none-any.whl (74 kB)
# Downloading typing_inspection-0.4.2-py3-none-any.whl (14 kB)
# Using cached typing_extensions-4.15.0-py3-none-any.whl (44 kB)
# Downloading zope_event-6.1-py3-none-any.whl (6.4 kB)
# Building wheels for collected packages: antlr4-python3-runtime
#   Building wheel for antlr4-python3-runtime (setup.py): started
#   Building wheel for antlr4-python3-runtime (setup.py): finished with status 'done'
#   Created wheel for antlr4-python3-runtime: filename=antlr4_python3_runtime-4.9.3-py3-none-any.whl size=144577 sha256=441445b799f585452fba9b95d391b77a8a4ba09467ce4836eceedddc478699b3
#   Stored in directory: c:\users\shesh\appdata\local\pip\cache\wheels\1f\be\48\13754633f1d08d1fbfc60d5e80ae1e5d7329500477685286cd
# Successfully built antlr4-python3-runtime
# Installing collected packages: schema, huey, flatbuffers, antlr4-python3-runtime, zope.event, waitress, typing_extensions, sympy, sqlparse, smdebug_rulesconfig, rsa, python-rapidjson, protobuf, prettytable, platformdirs, orderly-set, omegaconf, mock, ml_dtypes, json5, invoke, importlib-metadata, greenlet, graphql-core, annotated-doc, uvicorn, typing-inspection, tritonclient, torch, starlette, sagemaker_schema_inference_artifacts, opentelemetry-proto, opentelemetry-api, onnxruntime, onnx, graphql-relay, gevent, docker, deepdiff, botocore, skops, s3transfer, paramiko, opentelemetry-semantic-conventions, graphene, google-auth, geventhttpclient, Flask-CORS, opentelemetry-sdk, fastapi, databricks-sdk, boto3, awscli, sagemaker-core, mlflow-tracing, mlflow-skinny, mlflow, sagemaker-mlflow, sagemaker-train, sagemaker-serve, sagemaker-mlops, sagemaker
# Successfully installed Flask-CORS-6.0.2 annotated-doc-0.0.4 antlr4-python3-runtime-4.9.3 awscli-1.44.56 boto3-1.42.66 botocore-1.42.66 databricks-sdk-0.98.0 deepdiff-8.6.1 docker-7.1.0 fastapi-0.135.1 flatbuffers-25.12.19 gevent-25.9.1 geventhttpclient-2.3.9 google-auth-2.49.0 graphene-3.4.3 graphql-core-3.2.8 graphql-relay-3.2.0 greenlet-3.3.2 huey-2.6.0 importlib-metadata-6.11.0 invoke-2.2.1 json5-0.13.0 ml_dtypes-0.5.4 mlflow-3.10.1 mlflow-skinny-3.10.1 mlflow-tracing-3.10.1 mock-4.0.3 omegaconf-2.3.0 onnx-1.20.1 onnxruntime-1.24.3 opentelemetry-api-1.40.0 opentelemetry-proto-1.40.0 opentelemetry-sdk-1.40.0 opentelemetry-semantic-conventions-0.61b0 orderly-set-5.5.0 paramiko-4.0.0 platformdirs-4.9.4 prettytable-3.17.0 protobuf-6.33.5 python-rapidjson-1.23 rsa-4.7.2 s3transfer-0.16.0 sagemaker-3.5.0 sagemaker-core-2.5.0 sagemaker-mlflow-0.2.0 sagemaker-mlops-1.5.0 sagemaker-serve-1.5.0 sagemaker-train-1.5.0 sagemaker_schema_inference_artifacts-0.0.5 schema-0.7.8 skops-0.13.0 smdebug_rulesconfig-1.0.1 sqlparse-0.5.5 starlette-0.52.1 sympy-1.14.0 torch-2.10.0 tritonclient-2.66.0 typing-inspection-0.4.2 typing_extensions-4.15.0 uvicorn-0.41.0 waitress-3.0.2 zope.event-6.1
#   WARNING: The script huey_consumer.exe is installed in 'C:\Users\shesh\AppData\Roaming\Python\Python312\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script waitress-serve.exe is installed in 'C:\Users\shesh\AppData\Roaming\Python\Python312\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script isympy.exe is installed in 'C:\Users\shesh\AppData\Roaming\Python\Python312\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script sqlformat.exe is installed in 'C:\Users\shesh\AppData\Roaming\Python\Python312\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The scripts pyrsa-decrypt.exe, pyrsa-encrypt.exe, pyrsa-keygen.exe, pyrsa-priv2pub.exe, pyrsa-sign.exe and pyrsa-verify.exe are installed in 'C:\Users\shesh\AppData\Roaming\Python\Python312\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script pyjson5.exe is installed in 'C:\Users\shesh\AppData\Roaming\Python\Python312\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The scripts inv.exe and invoke.exe are installed in 'C:\Users\shesh\AppData\Roaming\Python\Python312\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script uvicorn.exe is installed in 'C:\Users\shesh\AppData\Roaming\Python\Python312\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The scripts torchfrtrace.exe and torchrun.exe are installed in 'C:\Users\shesh\AppData\Roaming\Python\Python312\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script onnxruntime_test.exe is installed in 'C:\Users\shesh\AppData\Roaming\Python\Python312\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The scripts backend-test-tools.exe, check-model.exe and check-node.exe are installed in 'C:\Users\shesh\AppData\Roaming\Python\Python312\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script deep.exe is installed in 'C:\Users\shesh\AppData\Roaming\Python\Python312\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script fastapi.exe is installed in 'C:\Users\shesh\AppData\Roaming\Python\Python312\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script mlflow.exe is installed in 'C:\Users\shesh\AppData\Roaming\Python\Python312\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script mlflow.exe is installed in 'C:\Users\shesh\AppData\Roaming\Python\Python312\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# aiobotocore 2.12.3 requires botocore<1.34.70,>=1.34.41, but you have botocore 1.42.66 which is incompatible.
# streamlit 1.37.1 requires protobuf<6,>=3.20, but you have protobuf 6.33.5 which is incompatible.

# %% [markdown]
# # Data processing

# %%
# %pip install pandas numpy pyarrow
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pandas in c:\programdata\anaconda3\lib\site-packages (2.2.2)
# Requirement already satisfied: numpy in c:\programdata\anaconda3\lib\site-packages (1.26.4)
# Requirement already satisfied: pyarrow in c:\programdata\anaconda3\lib\site-packages (16.1.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\programdata\anaconda3\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\programdata\anaconda3\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\programdata\anaconda3\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\programdata\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)

# %% [markdown]
# # Visualization

# %%
# %pip install matplotlib seaborn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: matplotlib in c:\programdata\anaconda3\lib\site-packages (3.9.2)
# Requirement already satisfied: seaborn in c:\programdata\anaconda3\lib\site-packages (0.13.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\programdata\anaconda3\lib\site-packages (from matplotlib) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\programdata\anaconda3\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\programdata\anaconda3\lib\site-packages (from matplotlib) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\programdata\anaconda3\lib\site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: numpy>=1.23 in c:\programdata\anaconda3\lib\site-packages (from matplotlib) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in c:\programdata\anaconda3\lib\site-packages (from matplotlib) (24.1)
# Requirement already satisfied: pillow>=8 in c:\programdata\anaconda3\lib\site-packages (from matplotlib) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\programdata\anaconda3\lib\site-packages (from matplotlib) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\programdata\anaconda3\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: pandas>=1.2 in c:\programdata\anaconda3\lib\site-packages (from seaborn) (2.2.2)
# Requirement already satisfied: pytz>=2020.1 in c:\programdata\anaconda3\lib\site-packages (from pandas>=1.2->seaborn) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\programdata\anaconda3\lib\site-packages (from pandas>=1.2->seaborn) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\programdata\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)

# %% [markdown]
# # Summarize

# %%
# %pip install protobuf==3.20.*
# !python --version
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting protobuf==3.20.*
#   Downloading protobuf-3.20.3-py2.py3-none-any.whl.metadata (720 bytes)
# Downloading protobuf-3.20.3-py2.py3-none-any.whl (162 kB)
# Installing collected packages: protobuf
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 6.33.5
#     Uninstalling protobuf-6.33.5:
#       Successfully uninstalled protobuf-6.33.5
# Successfully installed protobuf-3.20.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# databricks-sdk 0.98.0 requires protobuf!=5.26.*,!=5.27.*,!=5.28.*,!=5.29.0,!=5.29.1,!=5.29.2,!=5.29.3,!=5.29.4,!=6.30.0,!=6.30.1,!=6.31.0,<7.0,>=4.25.8, but you have protobuf 3.20.3 which is incompatible.
# onnx 1.20.1 requires protobuf>=4.25.1, but you have protobuf 3.20.3 which is incompatible.
# opentelemetry-proto 1.40.0 requires protobuf<7.0,>=5.0, but you have protobuf 3.20.3 which is incompatible.
# Python 3.12.7

# %%
# %pip list
# Out:
# Package                              Version
# ------------------------------------ ------------------
# aext-assistant                       4.1.0
# aext-assistant-server                4.1.0
# aext-core                            4.1.0
# aext-core-server                     4.1.0
# aext-panels                          4.1.0
# aext-panels-server                   4.1.0
# aext-project-filebrowser-server      4.1.0
# aext-share-notebook                  4.1.0
# aext-share-notebook-server           4.1.0
# aext-shared                          4.1.0
# aext-toolbox                         4.1.0
# aiobotocore                          2.12.3
# aiohappyeyeballs                     2.4.0
# aiohttp                              3.10.5
# aioitertools                         0.7.1
# aiosignal                            1.2.0
# alabaster                            0.7.16
# alembic                              1.13.3
# altair                               5.0.1
# anaconda-anon-usage                  0.4.4
# anaconda-auth                        0.8.6
# anaconda-catalogs                    0.2.0
# anaconda-cli-base                    0.5.2
# anaconda-client                      1.13.0
# anaconda-navigator                   2.6.6
# anaconda-project                     0.11.1
# annotated-doc                        0.0.4
# annotated-types                      0.6.0
# antlr4-python3-runtime               4.9.3
# anyio                                4.2.0
# appdirs                              1.4.4
# archspec                             0.2.3
# argon2-cffi                          21.3.0
# argon2-cffi-bindings                 21.2.0
# arrow                                1.2.3
# astroid                              2.14.2
# astropy                              6.1.3
# astropy-iers-data                    0.2024.9.2.0.33.23
# asttokens                            2.0.5
# async-lru                            2.0.4
# atomicwrites                         1.4.0
# attrs                                23.1.0
# Automat                              20.2.0
# autopep8                             2.0.4
# awscli                               1.44.56
# Babel                                2.11.0
# bcrypt                               3.2.0
# beautifulsoup4                       4.12.3
# binaryornot                          0.4.4
# black                                24.8.0
# bleach                               4.1.0
# blinker                              1.6.2
# bokeh                                3.6.0
# boltons                              23.0.0
# boto3                                1.42.66
# botocore                             1.42.66
# Bottleneck                           1.3.7
# Brotli                               1.0.9
# cachetools                           5.3.3
# certifi                              2025.8.3
# cffi                                 1.17.1
# chardet                              4.0.0
# charset-normalizer                   3.3.2
# click                                8.1.7
# cloudpickle                          3.0.0
# colorama                             0.4.6
# colorcet                             3.1.0
# comm                                 0.2.1
# conda                                24.11.3
# conda-build                          24.9.0
# conda-content-trust                  0.2.0
# conda_index                          0.5.0
# conda-libmamba-solver                24.9.0
# conda-pack                           0.7.1
# conda-package-handling               2.3.0
# conda_package_streaming              0.10.0
# conda-repo-cli                       1.0.114
# conda-token                          0.6.0
# constantly                           23.10.4
# contourpy                            1.2.0
# cookiecutter                         2.6.0
# cryptography                         43.0.0
# cssselect                            1.2.0
# cycler                               0.11.0
# cytoolz                              0.12.2
# dask                                 2024.8.2
# dask-expr                            1.1.13
# databricks-sdk                       0.98.0
# datashader                           0.16.3
# debugpy                              1.6.7
# decorator                            5.1.1
# deepdiff                             8.6.1
# defusedxml                           0.7.1
# diff-match-patch                     20200713
# dill                                 0.3.8
# distributed                          2024.8.2
# distro                               1.9.0
# docker                               7.1.0
# docstring-to-markdown                0.11
# docutils                             0.18.1
# et-xmlfile                           1.1.0
# executing                            0.8.3
# fastapi                              0.135.1
# fastjsonschema                       2.16.2
# filelock                             3.13.1
# findspark                            2.0.1
# flake8                               7.0.0
# Flask                                3.0.3
# flask-cors                           6.0.2
# flatbuffers                          25.12.19
# fonttools                            4.51.0
# frozendict                           2.4.2
# frozenlist                           1.4.0
# fsspec                               2024.6.1
# gensim                               4.3.3
# gevent                               25.9.1
# geventhttpclient                     2.3.9
# gitdb                                4.0.7
# GitPython                            3.1.43
# google-auth                          2.49.0
# graphene                             3.4.3
# graphql-core                         3.2.8
# graphql-relay                        3.2.0
# greenlet                             3.3.2
# h11                                  0.14.0
# h5py                                 3.11.0
# HeapDict                             1.0.1
# holoviews                            1.19.1
# httpcore                             1.0.2
# httpx                                0.27.0
# huey                                 2.6.0
# hvplot                               0.11.0
# hyperlink                            21.0.0
# idna                                 3.7
# imagecodecs                          2023.1.23
# imageio                              2.33.1
# imagesize                            1.4.1
# imbalanced-learn                     0.12.3
# importlib-metadata                   6.11.0
# incremental                          22.10.0
# inflection                           0.5.1
# iniconfig                            1.1.1
# intake                               2.0.7
# intervaltree                         3.1.0
# invoke                               2.2.1
# ipykernel                            6.28.0
# ipython                              8.27.0
# ipython-genutils                     0.2.0
# ipywidgets                           7.8.1
# isort                                5.13.2
# itemadapter                          0.3.0
# itemloaders                          1.1.0
# itsdangerous                         2.2.0
# jaraco.classes                       3.2.1
# jedi                                 0.19.1
# jellyfish                            1.0.1
# Jinja2                               3.1.4
# jmespath                             1.0.1
# joblib                               1.4.2
# json5                                0.13.0
# jsonpatch                            1.33
# jsonpointer                          2.1
# jsonschema                           4.23.0
# jsonschema-specifications            2023.7.1
# jupyter                              1.0.0
# jupyter_client                       8.6.0
# jupyter-console                      6.6.3
# jupyter_core                         5.7.2
# jupyter-events                       0.10.0
# jupyter-lsp                          2.2.0
# jupyter_server                       2.14.1
# jupyter_server_terminals             0.4.4
# jupyterlab                           4.2.5
# jupyterlab-pygments                  0.1.2
# jupyterlab_server                    2.27.3
# jupyterlab-widgets                   1.0.0
# keyring                              24.3.1
# kiwisolver                           1.4.4
# lazy_loader                          0.4
# lazy-object-proxy                    1.10.0
# lckr_jupyterlab_variableinspector    3.1.0
# libarchive-c                         5.1
# libmambapy                           1.5.8
# linkify-it-py                        2.0.0
# llvmlite                             0.43.0
# lmdb                                 1.4.1
# locket                               1.0.0
# lxml                                 5.2.1
# lz4                                  4.3.2
# Mako                                 1.2.3
# Markdown                             3.4.1
# markdown-it-py                       2.2.0
# MarkupSafe                           2.1.3
# matplotlib                           3.9.2
# matplotlib-inline                    0.1.6
# mccabe                               0.7.0
# mdit-py-plugins                      0.3.0
# mdurl                                0.1.0
# menuinst                             2.1.2
# mistune                              2.0.4
# mkl_fft                              1.3.10
# mkl_random                           1.2.7
# mkl-service                          2.4.0
# ml_dtypes                            0.5.4
# mlflow                               3.10.1
# mlflow-skinny                        3.10.1
# mlflow-tracing                       3.10.1
# mock                                 4.0.3
# more-itertools                       10.3.0
# mpmath                               1.3.0
# msgpack                              1.0.3
# multidict                            6.0.4
# multipledispatch                     0.6.0
# mypy                                 1.11.2
# mypy-extensions                      1.0.0
# mysql-connector-python               9.4.0
# navigator-updater                    0.5.1
# nb_conda_kernels                     2.5.2
# nbclient                             0.8.0
# nbconvert                            7.16.4
# nbformat                             5.10.4
# nest-asyncio                         1.6.0
# networkx                             3.3
# nltk                                 3.9.1
# notebook                             7.2.2
# notebook_shim                        0.2.3
# numba                                0.60.0
# numexpr                              2.8.7
# numpy                                1.26.4
# numpydoc                             1.7.0
# omegaconf                            2.3.0
# onnx                                 1.20.1
# onnxruntime                          1.24.3
# openpyxl                             3.1.5
# opentelemetry-api                    1.40.0
# opentelemetry-proto                  1.40.0
# opentelemetry-sdk                    1.40.0
# opentelemetry-semantic-conventions   0.61b0
# orderly-set                          5.5.0
# overrides                            7.4.0
# packaging                            24.1
# pandas                               2.2.2
# pandocfilters                        1.5.0
# panel                                1.5.2
# param                                2.1.1
# paramiko                             4.0.0
# parsel                               1.8.1
# parso                                0.8.3
# partd                                1.4.1
# pathspec                             0.10.3
# patsy                                0.5.6
# pexpect                              4.8.0
# pickleshare                          0.7.5
# pillow                               10.4.0
# pip                                  24.2
# pkce                                 1.0.3
# pkginfo                              1.10.0
# platformdirs                         4.9.4
# plotly                               5.24.1
# pluggy                               1.0.0
# ply                                  3.11
# prettytable                          3.17.0
# prometheus-client                    0.14.1
# prompt-toolkit                       3.0.43
# Protego                              0.1.16
# protobuf                             3.20.3
# psutil                               5.9.0
# ptyprocess                           0.7.0
# pure-eval                            0.2.2
# py-cpuinfo                           9.0.0
# py4j                                 0.10.9.7
# pyarrow                              16.1.0
# pyasn1                               0.4.8
# pyasn1-modules                       0.2.8
# pycodestyle                          2.11.1
# pycosat                              0.6.6
# pycparser                            2.21
# pyct                                 0.5.0
# pycurl                               7.45.3
# pydantic                             2.8.2
# pydantic_core                        2.20.1
# pydantic-settings                    2.6.1
# pydeck                               0.8.0
# PyDispatcher                         2.0.5
# pydocstyle                           6.3.0
# pyerfa                               2.0.1.4
# pyflakes                             3.2.0
# Pygments                             2.15.1
# PyJWT                                2.8.0
# pylint                               2.16.2
# pylint-venv                          3.0.3
# pyls-spyder                          0.4.0
# PyNaCl                               1.5.0
# pyodbc                               5.1.0
# pyOpenSSL                            24.2.1
# pyparsing                            3.1.2
# PyQt5                                5.15.10
# PyQt5-sip                            12.13.0
# PyQtWebEngine                        5.15.6
# PySocks                              1.7.1
# pyspark                              3.5.5
# pytest                               7.4.4
# python-dateutil                      2.9.0.post0
# python-dotenv                        0.21.0
# python-json-logger                   2.0.7
# python-lsp-black                     2.0.0
# python-lsp-jsonrpc                   1.1.2
# python-lsp-server                    1.10.0
# python-rapidjson                     1.23
# python-slugify                       5.0.2
# pytoolconfig                         1.2.6
# pytz                                 2024.1
# pyviz_comms                          3.0.2
# PyWavelets                           1.7.0
# pywin32                              305.1
# pywin32-ctypes                       0.2.2
# pywinpty                             2.0.10
# PyYAML                               6.0.1
# pyzmq                                25.1.2
# QDarkStyle                           3.2.3
# qstylizer                            0.2.2
# QtAwesome                            1.3.1
# qtconsole                            5.5.1
# QtPy                                 2.4.1
# queuelib                             1.6.2
# readchar                             4.0.5
# referencing                          0.30.2
# regex                                2024.9.11
# requests                             2.32.3
# requests-file                        1.5.1
# requests-toolbelt                    1.0.0
# rfc3339-validator                    0.1.4
# rfc3986-validator                    0.1.1
# rich                                 13.7.1
# rope                                 1.12.0
# rpds-py                              0.10.6
# rsa                                  4.7.2
# Rtree                                1.0.1
# ruamel.yaml                          0.18.6
# ruamel.yaml.clib                     0.2.8
# ruamel-yaml-conda                    0.17.21
# s3fs                                 2024.6.1
# s3transfer                           0.16.0
# sagemaker                            3.5.0
# sagemaker-core                       2.5.0
# sagemaker-mlflow                     0.2.0
# sagemaker-mlops                      1.5.0
# sagemaker-schema-inference-artifacts 0.0.5
# sagemaker-serve                      1.5.0
# sagemaker-train                      1.5.0
# schema                               0.7.8
# scikit-image                         0.24.0
# scikit-learn                         1.5.1
# scipy                                1.13.1
# Scrapy                               2.11.1
# seaborn                              0.13.2
# semver                               3.0.2
# Send2Trash                           1.8.2
# sentry-sdk                           2.18.0
# service-identity                     18.1.0
# setuptools                           75.1.0
# shellingham                          1.5.0
# sip                                  6.7.12
# six                                  1.16.0
# skops                                0.13.0
# smart-open                           5.2.1
# smdebug-rulesconfig                  1.0.1
# smmap                                4.0.0
# sniffio                              1.3.0
# snowballstemmer                      2.2.0
# sortedcontainers                     2.4.0
# soupsieve                            2.5
# Sphinx                               7.3.7
# sphinxcontrib-applehelp              1.0.2
# sphinxcontrib-devhelp                1.0.2
# sphinxcontrib-htmlhelp               2.0.0
# sphinxcontrib-jsmath                 1.0.1
# sphinxcontrib-qthelp                 1.0.3
# sphinxcontrib-serializinghtml        1.1.10
# spyder                               5.5.1
# spyder-kernels                       2.5.0
# SQLAlchemy                           2.0.34
# sqlparse                             0.5.5
# stack-data                           0.2.0
# starlette                            0.52.1
# statsmodels                          0.14.2
# streamlit                            1.37.1
# sympy                                1.14.0
# tables                               3.10.1
# tabulate                             0.9.0
# tblib                                1.7.0
# tenacity                             8.2.3
# terminado                            0.17.1
# text-unidecode                       1.3
# textdistance                         4.2.1
# threadpoolctl                        3.5.0
# three-merge                          0.1.1
# tifffile                             2023.4.12
# tinycss2                             1.2.1
# tldextract                           5.1.2
# toml                                 0.10.2
# tomli                                2.0.1
# tomlkit                              0.11.1
# toolz                                0.12.0
# torch                                2.10.0
# tornado                              6.4.1
# tqdm                                 4.66.5
# traitlets                            5.14.3
# tritonclient                         2.66.0
# truststore                           0.8.0
# Twisted                              23.10.0
# twisted-iocpsupport                  1.0.2
# typer                                0.9.0
# typing_extensions                    4.15.0
# typing-inspection                    0.4.2
# tzdata                               2023.3
# uc-micro-py                          1.0.1
# ujson                                5.10.0
# unicodedata2                         15.1.0
# Unidecode                            1.3.8
# urllib3                              2.2.3
# uvicorn                              0.41.0
# w3lib                                2.1.2
# waitress                             3.0.2
# watchdog                             4.0.1
# wcwidth                              0.2.5
# webencodings                         0.5.1
# websocket-client                     1.8.0
# Werkzeug                             3.0.3
# whatthepatch                         1.0.2
# wheel                                0.44.0
# widgetsnbextension                   3.6.6
# win-inet-pton                        1.1.0
# wrapt                                1.14.1
# xarray                               2023.6.0
# xlwings                              0.32.1
# xyzservices                          2022.9.0
# yapf                                 0.40.2
# yarl                                 1.11.0
# zict                                 3.0.0
# zipp                                 3.17.0
# zope.event                           6.1
# zope.interface                       5.4.0
# zstandard                            0.23.0

# %%
setup_dependencies_passed = True

# %%
# %store setup_dependencies_passed
# Out:
# Stored 'setup_dependencies_passed' (bool)

# %%
# %store
# Out:
# Stored variables and their in-db values:
# setup_dependencies_passed             -> True

# %% [markdown]
# # Release Resources

# %%
# %%html
#
# Shutting down your kernel for this notebook to release resources.
# Out:
# Shutting down your kernel for this notebook to release resources.

# %%
# %%javascript
#
# try {
#     Jupyter.notebook.save_checkpoint();
#     Jupyter.notebook.session.delete();
# }
# catch(err) {
#     // NoOp
# }
