# %% [markdown]
# # Upgrade pip

# %%
# %pip install --upgrade pip

# %% [markdown]
# # AWS

# %%
# %pip install boto3 awscli sagemaker

# %% [markdown]
# # Data processing

# %%
# %pip install pandas numpy pyarrow s3fs

# %% [markdown]
# # Machine learning

# %%
# %pip install xgboost scikit-learn

# %% [markdown]
# # Database query

# %%
# %pip install pyathena sqlalchemy

# %% [markdown]
# # Weather data

# %%
# %pip install meteostat

# %% [markdown]
# # Geolocation

# %%
# %pip install geopy

# %% [markdown]
# # Visualization

# %%
# %pip install matplotlib seaborn plotly dash

# %% [markdown]
# # API request and Utilities

# %%
# %pip install requests protobuf==3.20.*

# %% [markdown]
# # Verify versions

# %%
# %pip list

# %% [markdown]
# # Confirm setup complete

# %%
setup_dependencies_passed = True
# %store setup_dependencies_passed
print("All dependencies installed successfully")

# %% [markdown]
# #  Release resources

# %%
# %%html
# <p>Shutting down kernel to release resources.</p>

# %%
# %%javascript
# try {
#     Jupyter.notebook.save_checkpoint();
#     Jupyter.notebook.session.delete();
# }
# catch(err) {}
